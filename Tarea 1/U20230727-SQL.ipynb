-- %% [markdown]
-- # [Hospital]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [Hospital]    Script Date: 09/02/2024 15:52:05 ******/
CREATE DATABASE [Hospital]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'Hospital', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.MSSQLSERVER\MSSQL\DATA\Hospital.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'Hospital_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.MSSQLSERVER\MSSQL\DATA\Hospital_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT, LEDGER = OFF
GO
ALTER DATABASE [Hospital] SET COMPATIBILITY_LEVEL = 160
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [Hospital].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [Hospital] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [Hospital] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [Hospital] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [Hospital] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [Hospital] SET ARITHABORT OFF 
GO
ALTER DATABASE [Hospital] SET AUTO_CLOSE ON 
GO
ALTER DATABASE [Hospital] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [Hospital] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [Hospital] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [Hospital] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [Hospital] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [Hospital] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [Hospital] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [Hospital] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [Hospital] SET  ENABLE_BROKER 
GO
ALTER DATABASE [Hospital] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [Hospital] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [Hospital] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [Hospital] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [Hospital] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [Hospital] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [Hospital] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [Hospital] SET RECOVERY SIMPLE 
GO
ALTER DATABASE [Hospital] SET  MULTI_USER 
GO
ALTER DATABASE [Hospital] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [Hospital] SET DB_CHAINING OFF 
GO
ALTER DATABASE [Hospital] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [Hospital] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [Hospital] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [Hospital] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
ALTER DATABASE [Hospital] SET QUERY_STORE = ON
GO
ALTER DATABASE [Hospital] SET QUERY_STORE (OPERATION_MODE = READ_WRITE, CLEANUP_POLICY = (STALE_QUERY_THRESHOLD_DAYS = 30), DATA_FLUSH_INTERVAL_SECONDS = 900, INTERVAL_LENGTH_MINUTES = 60, MAX_STORAGE_SIZE_MB = 1000, QUERY_CAPTURE_MODE = AUTO, SIZE_BASED_CLEANUP_MODE = AUTO, MAX_PLANS_PER_QUERY = 200, WAIT_STATS_CAPTURE_MODE = ON)
GO

-- %% [markdown]
-- # [dbo].[Consultas]

-- %%
USE [Hospital]
GO

-- %%
/****** Object:  Table [dbo].[Consultas]    Script Date: 09/02/2024 15:52:05 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Consultas](
	[ConsultasID] [int] IDENTITY(1,1) NOT NULL,
	[PacienteID] [int] NULL,
	[RazonConsulta] [varchar](90) NULL,
PRIMARY KEY CLUSTERED 
(
	[ConsultasID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[departamentos]

-- %%
/****** Object:  Table [dbo].[departamentos]    Script Date: 09/02/2024 15:52:05 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[departamentos](
	[DepartamentoID] [int] IDENTITY(1,1) NOT NULL,
	[Hematologia] [varchar](80) NULL,
	[Neutologia] [varchar](80) NULL,
	[Quirurgica] [varchar](80) NULL,
PRIMARY KEY CLUSTERED 
(
	[DepartamentoID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Historial]

-- %%
/****** Object:  Table [dbo].[Historial]    Script Date: 09/02/2024 15:52:05 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Historial](
	[HistorialID] [int] IDENTITY(1,1) NOT NULL,
	[PacienteID] [int] NULL,
	[ConsultasID] [int] NULL,
	[ProcesosMedicosID] [int] NULL,
	[Resultados] [varchar](90) NULL,
	[FechaProceso] [date] NULL,
PRIMARY KEY CLUSTERED 
(
	[HistorialID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Pacientes]

-- %%
/****** Object:  Table [dbo].[Pacientes]    Script Date: 09/02/2024 15:52:05 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Pacientes](
	[PacienteID] [int] IDENTITY(1,1) NOT NULL,
	[PersonalMedicoID] [int] NULL,
	[ConsultaID] [int] NULL,
	[Nombre] [varchar](50) NULL,
	[Edad] [int] NULL,
	[Apellido] [varchar](50) NULL,
PRIMARY KEY CLUSTERED 
(
	[PacienteID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[PersonalAdmin]

-- %%
/****** Object:  Table [dbo].[PersonalAdmin]    Script Date: 09/02/2024 15:52:05 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[PersonalAdmin](
	[PersonalAdministrativoID] [int] IDENTITY(1,1) NOT NULL,
	[Mantenimiento] [varchar](70) NULL,
	[Asistentes] [varchar](70) NULL,
	[Gerencia] [varchar](70) NULL,
	[DepartamentoID] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[PersonalAdministrativoID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[PersonalMedico]

-- %%
/****** Object:  Table [dbo].[PersonalMedico]    Script Date: 09/02/2024 15:52:05 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[PersonalMedico](
	[PersonalMedicoID] [int] IDENTITY(1,1) NOT NULL,
	[Doctores] [varchar](60) NULL,
	[Psicologos] [varchar](60) NULL,
	[Enfermeros] [varchar](60) NULL,
	[DepartamentoID] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[PersonalMedicoID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[ProcesosMedicos]

-- %%
/****** Object:  Table [dbo].[ProcesosMedicos]    Script Date: 09/02/2024 15:52:05 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[ProcesosMedicos](
	[ProcesosMedicosID] [int] IDENTITY(1,1) NOT NULL,
	[PacienteID] [int] NULL,
	[FechaProceso] [date] NULL,
PRIMARY KEY CLUSTERED 
(
	[ProcesosMedicosID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [FK__Consultas__Pacie__571DF1D5]

-- %%
ALTER TABLE [dbo].[Consultas]  WITH CHECK ADD FOREIGN KEY([PacienteID])
REFERENCES [dbo].[Pacientes] ([PacienteID])
GO

-- %% [markdown]
-- # [FK__Historial__Consu__60A75C0F]

-- %%
ALTER TABLE [dbo].[Historial]  WITH CHECK ADD FOREIGN KEY([ConsultasID])
REFERENCES [dbo].[Consultas] ([ConsultasID])
GO

-- %% [markdown]
-- # [FK__Historial__Pacie__5FB337D6]

-- %%
ALTER TABLE [dbo].[Historial]  WITH CHECK ADD FOREIGN KEY([PacienteID])
REFERENCES [dbo].[Pacientes] ([PacienteID])
GO

-- %% [markdown]
-- # [FK__Pacientes__Perso__5165187F]

-- %%
ALTER TABLE [dbo].[Pacientes]  WITH CHECK ADD FOREIGN KEY([PersonalMedicoID])
REFERENCES [dbo].[PersonalMedico] ([PersonalMedicoID])
GO

-- %% [markdown]
-- # [FK__PersonalA__Depar__4E88ABD4]

-- %%
ALTER TABLE [dbo].[PersonalAdmin]  WITH CHECK ADD FOREIGN KEY([DepartamentoID])
REFERENCES [dbo].[departamentos] ([DepartamentoID])
GO

-- %% [markdown]
-- # [FK__PersonalM__Depar__4BAC3F29]

-- %%
ALTER TABLE [dbo].[PersonalMedico]  WITH CHECK ADD FOREIGN KEY([DepartamentoID])
REFERENCES [dbo].[departamentos] ([DepartamentoID])
GO

-- %% [markdown]
-- # [FK__ProcesosM__Pacie__5441852A]

-- %%
ALTER TABLE [dbo].[ProcesosMedicos]  WITH CHECK ADD FOREIGN KEY([PacienteID])
REFERENCES [dbo].[Pacientes] ([PacienteID])
GO

-- %% [markdown]
-- # [Hospital]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [Hospital] SET  READ_WRITE 
GO
